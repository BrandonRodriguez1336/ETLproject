# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/ca25935/Desktop/UCD Data Analytics/Homework/ETL project/data/cleaned/CSVs/state_M2018_dl.csv")
data1 = pd.read_csv("C:/Users/ca25935/Desktop/UCD Data Analytics/Homework/ETL project/data/cleaned/CSVs/ETLproject/data original files/enigma_census_data_2016.csv")

# %%
data.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#      TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1,943,760      0.4  1000.000  1.00  ...    16.22   25.63   38.28  18,030
# 1     73,860      1.1    38.001  0.72  ...    46.01   63.87   90.06  48,650
# 2      1,390      5.6     0.716  0.53  ...    91.31       #       #  79,530
# 3     28,600      1.8    14.712  0.93  ...    48.55   70.79       #  50,180
# 4        970      6.4     0.498  1.43  ...        *       *       *  16,310
#
#    A_PCT25 A_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY
# ...

# %%
data = data.replace(['#','**','*'],0)

data
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 36892    78  VI  Virgin Islands  53-6031
# 36893    78  VI  Virgin Islands  53-6099
# 36894    78  VI  Virgin Islands  53-7051
# 36895    78  VI  Virgin Islands  53-7062
# 36896    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP    TOT_EMP  \
# 0                                        All Occupations     total  1,943,760
# 1                                 Management Occupations     major     73,860
# 2                                       Chief Executives  detailed      1,390
# 3                        General and Operations Managers  detailed     28,600
# ...

# %%
data.to_csv('C:/Users/ca25935/Desktop/UCD Data Analytics/Homework/ETL project/data/cleaned/CSVs/ETLproject/data cleaned/state_M2018_dl_cleaned.csv')

# %%
data1 = data1.replace(['(X)','-','**'], 0)
data1 = data1.replace(0, np.nan)
data1 = data1.dropna(how='any', axis=0)
data1
# Out:
#                                  Occupational_Category  \
# 0                                                Total
# 1    Management, Business, Science, and Arts Occupa...
# 2      Management, Business, and Financial Occupations
# 3                               Management Occupations
# 4                                     Chief executives
# ..                                                 ...
# 543                        Material Moving Occupations
# 548             Industrial truck and tractor operators
# 549                 Cleaners of vehicles and equipment
# 550  Laborers and freight, stock, and material move...
# 552                        Packers and packagers, hand
#
#      Number_of_Full_Time_Year_Round_Workers_Total_Estimate  \
# 0                                            106609098
# 1                                             44274859
# 2                                             19812917
# 3                                             13689475
# ...

# %%
data1.to_csv('C:/Users/ca25935/Desktop/UCD Data Analytics/Homework/ETL project/data/cleaned/CSVs/ETLproject/data cleaned/enigma_census_data_2016.csv')
